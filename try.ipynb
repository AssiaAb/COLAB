# %% [markdown]
# <a href="https://colab.research.google.com/github/AssiaAb/COLAB/blob/main/try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tensorflow numpy matplotlib

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
minst=tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=minst.load_data()

x_train,x_test=x_train/255.0, x_test/255.0


plt.imshow(x_train[0] ,cmap="gray")
plt.title(f" label: y_train[0]")
plt.show()

print(x_train.shape)
print(x_test.shape)
print(y_train[:10])
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 28, 28)
# (10000, 28, 28)
# [5 0 4 1 9 2 1 3 1 4]

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

# Charger le dataset CIFAR-10
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Normalisation des images (mise à l'échelle entre 0 et 1)
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
model = keras.Sequential([
    keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(32, 32, 3)),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64, (3,3), activation='relu'),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(128, (3,3), activation='relu'),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])
# Compilation du modèle
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Entraînement du modèle
epochs = 10  # Nombre d'époques
history = model.fit(x_train, y_train, epochs=epochs, validation_data=(x_test, y_test))
# Évaluation du modèle
loss, acc = model.evaluate(x_test, y_test)
print(f"Précision du modèle : {acc*100:.2f}%")

# Affichage de l'historique d'entraînement
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Époque')
plt.ylabel('Précision')
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 51ms/step - accuracy: 0.3618 - loss: 1.7112 - val_accuracy: 0.5740 - val_loss: 1.1771
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 78s 49ms/step - accuracy: 0.6020 - loss: 1.1250 - val_accuracy: 0.6352 - val_loss: 1.0284
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 49ms/step - accuracy: 0.6710 - loss: 0.9407 - val_accuracy: 0.6817 - val_loss: 0.9140
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 52ms/step - accuracy: 0.7189 - loss: 0.8078 - val_accuracy: 0.7015 - val_loss: 0.8572
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 78s 50ms/step - accuracy: 0.7532 - loss: 0.7008 - val_accuracy: 0.7011 - val_loss: 0.8616
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 52ms/step - accuracy: 0.7779 - loss: 0.6294 - val_accuracy: 0.7123 - val_loss: 0.8607
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 78s 50ms/step - accuracy: 0.8023 - loss: 0.5619 - val_accuracy: 0.7106 - val_loss: 0.8711
# Epoch 8/10
# ...
